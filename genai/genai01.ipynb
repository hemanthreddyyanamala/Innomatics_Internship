# %%
from dotenv import load_dotenv
import os
load_dotenv()
api_key = os.getenv("GEMINI_API_KEY")

# %%
pip install -q -U google-genai
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script websockets.exe is installed in 'C:\Users\heman\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pyrsa-decrypt.exe, pyrsa-encrypt.exe, pyrsa-keygen.exe, pyrsa-priv2pub.exe, pyrsa-sign.exe and pyrsa-verify.exe are installed in 'C:\Users\heman\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'C:\Users\heman\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from google import genai
client=genai.Client()#client=OpenAI(),Groq(),Mistral()
response=client.models.generate_content(
    model='gemini-3-flash-preview',
    contents='what is life?'
)

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""The question "What is life?" is one of the deepest and most complex questions humans have ever asked. Because it spans so many fields, the answer depends entirely on the lens through which you are looking.
#
# Here are the four primary ways we define life:
#
# ### 1. The Biological Perspective (The "How")
# Biologists define life by what it **does**. There is no single perfect definition, but most scientists agree that for something to be considered "alive," it generally must exhibit these traits:
# *   **Metabolism:** Converting energy (from food or sunlight) into fuel to maintain cellular function.
# *   **Reproduction:** The ability to produce offspring, passing on genetic information (DNA).
# *   **Homeostasis:** Maintaining a stable internal environment (like body temperature) despite changes outside.
# *   **Growth and Development:** Increasing in size or complexity over time.
# *   **Response to Stimuli:** Reacting to the environment (e.g., a plant turning toward the light).
# *   **Evolution:** The capacity for populations to change over generations to adapt to their environment.
#
# *Note: This definition is still debated because things like viruses or "self-replicating proteins" (prions) sit on the border between living and non-living.*
#
# ### 2. The Physical Perspective (The "Energy")
# In physics, particularly thermodynamics, life is seen as a way to resist the natural order of the universe.
# *   **Entropy:** The Second Law of Thermodynamics states that the universe tends toward disorder (entropy).
# *   **Life as "Negentropy":** Physicist Erwin Schrödinger described life as something that feeds on "negative entropy." Life takes in energy to create complex structures and maintain order, temporarily holding back the chaos that eventually claims all matter.
#
# ### 3. The Philosophical Perspective (The "Why")
# This looks for the **meaning** of life rather than the mechanics of it. There are three major schools of thought:
# *   **Nihilism:** Life has no intrinsic meaning or value. We are a biological accident in an indifferent universe.
# *   **Essentialism/Religion:** Life has a pre-ordained purpose, often given by a higher power or a cosmic order.
# *   **Existentialism:** Life has no *inherent* meaning, but that gives you the freedom to **create your own.** As Jean-Paul Sartre suggested, "existence precedes essence"—you exist first, and then you define who you are through your choices.
#
# ### 4. The Experiential Perspective (The "Feeling")
# From a personal, human standpoint, life is **consciousness**. It is the subjective experience of being "someone."
# *   It is the collection of memories, relationships, sensations, and emotions.
# *   It is the ability to perceive the universe. As astronomer Carl Sagan famously said, "We are a way for the cosmos to know itself." Without life to observe it, the universe would exist, but it wouldn't be *felt*.
#
# ---
#
# ### The Synthesis
# If you combine these views, you could say:
#
# **Life is a rare and brief state of matter that uses energy to maintain order, reproduce itself, and—in its most complex forms—experience and wonder about its own existence.**
#
# Which of those perspectives resonates most with you? Are you looking for the scientific "how" or the philosophical "why"?""",
#             thought_signature=b"\x12\xe8\x11\n\xe5\x11\x01\xbe>\xf6\xfb\x11\x89\xeb\xa1\x92\xfdW\xe7\xcfu\xc8\xce\xcbe\x95.,\xbc\x18_vq\x84\xaf\x0co\x00\x04\xdd\xa31'\x04\xfa\xc4\xa8\xcah\r\xf1\x82\xe0\x13\xbc\xff6\xf3\x00\xbd\x8bj\x92\xc4\xc8{\xd8\\\\\xb0f6\xa8\xe7\x93\xa8\x9f[\xe9SWt\xb1%\xf2\x1b\xc9\x15\xc2\x05P$4\xe1]^(...'
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-3-flash-preview',
#   response_id='IYiMaafPLsyBqfkPi7zq2QY',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=704,
#     prompt_token_count=5,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=5
#       ),
#     ],
#     thoughts_token_count=567,
#     total_token_count=1276
#   )
# )

# %%
response.text
# Out:
# 'The question "What is life?" is one of the deepest and most complex questions humans have ever asked. Because it spans so many fields, the answer depends entirely on the lens through which you are looking.\n\nHere are the four primary ways we define life:\n\n### 1. The Biological Perspective (The "How")\nBiologists define life by what it **does**. There is no single perfect definition, but most scientists agree that for something to be considered "alive," it generally must exhibit these traits:\n*   **Metabolism:** Converting energy (from food or sunlight) into fuel to maintain cellular function.\n*   **Reproduction:** The ability to produce offspring, passing on genetic information (DNA).\n*   **Homeostasis:** Maintaining a stable internal environment (like body temperature) despite changes outside.\n*   **Growth and Development:** Increasing in size or complexity over time.\n*   **Response to Stimuli:** Reacting to the environment (e.g., a plant turning toward the light).\n*   **Evolution:** The capacity for populations to change over generations to adapt to their environment.\n\n*Note: This definition is still debated because things like viruses or "self-replicating proteins" (prions) sit on the border between living and non-living.*\n\n### 2. The Physical Perspective (The "Energy")\nIn physics, particularly thermodynamics, life is seen as a way to resist the natural order of the universe.\n*   **Entropy:** The Second Law of Thermodynamics states that the universe tends toward disorder (entropy). \n*   **Life as "Negentropy":** Physicist Erwin Schrödinger described life as something that feeds on "negative entropy." Life takes in energy to create complex structures and maintain order, temporarily holding back the chaos that eventually claims all matter.\n\n### 3. The Philosophical Perspective (The "Why")\nThis looks for the **meaning** of life rather than the mechanics of it. There are three major schools of thought:\n*   **Nihilism:** Life has no intrinsic meaning or value. We are a biological accident in an indifferent universe.\n*   **Essentialism/Religion:** Life has a pre-ordained purpose, often given by a higher power or a cosmic order.\n*   **Existentialism:** Life has no *inherent* meaning, but that gives you the freedom to **create your own.** As Jean-Paul Sartre suggested, "existence precedes essence"—you exist first, and then you define who you are through your choices.\n\n### 4. The Experiential Perspective (The "Feeling")\nFrom a personal, human standpoint, life is **consciousness**. It is the subjective experience of being "someone."\n*   It is the collection of memories, relationships, sensations, and emotions.\n*   It is the ability to perceive the universe. As astronomer Carl Sagan famously said, "We are a way for the cosmos to know itself." Without life to observe it, the universe would exist, but it wouldn\'t be *felt*.\n\n---\n\n### The Synthesis\nIf you combine these views, you could say:\n\n**Life is a rare and brief state of matter that uses energy to maintain order, reproduce itself, and—in its most complex forms—experience and wonder about its own existence.**\n\nWhich of those perspectives resonates most with you? Are you looking for the scientific "how" or the philosophical "why"?'

# %% [markdown]
# ## build a question answering system using groq genai

# %%
from groq import Groq
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from groq import Groq
#
# File c:\Users\heman\OneDrive\Desktop\AFTER BTECH\innomatics\internship\genai\venv\Lib\site-packages\groq\__init__.py:5
#       1 # File generated from our OpenAPI spec by Stainless. See CONTRIBUTING.md for details.
#       3 import typing as _t
# ----> 5 from . import types
#       6 from ._types import NOT_GIVEN, Omit, NoneType, NotGiven, Transport, ProxiesTypes, omit, not_given
#       7 from ._utils import file_from_path
#
# File c:\Users\heman\OneDrive\Desktop\AFTER BTECH\innomatics\internship\genai\venv\Lib\site-packages\groq\types\__init__.py:5
#       1 # File generated from our OpenAPI spec by Stainless. See CONTRIBUTING.md for details.
#       3 from __future__ import annotations
# ----> 5 from .model import Model as Model
#       6 from .shared import (
#       7     ErrorObject as ErrorObject,
#       8     FunctionDefinition as FunctionDefinition,
#       9     FunctionParameters as FunctionParameters,
#      10 )
#      11 from .embedding import Embedding as Embedding
#
# File c:\Users\heman\OneDrive\Desktop\AFTER BTECH\innomatics\internship\genai\venv\Lib\site-packages\groq\types\model.py:5
#       1 # File generated from our OpenAPI spec by Stainless. See CONTRIBUTING.md for details.
#       3 from typing_extensions import Literal
# ----> 5 from .._models import BaseModel
#       7 __all__ = ["Model"]
#      10 class Model(BaseModel):
#
# File c:\Users\heman\OneDrive\Desktop\AFTER BTECH\innomatics\internship\genai\venv\Lib\site-packages\groq\_models.py:23
#       7 from datetime import date, datetime
#       8 from typing_extensions import (
#       9     List,
#      10     Unpack,
#    (...)     20     runtime_checkable,
#      21 )
# ---> 23 import pydantic
#      24 from pydantic.fields import FieldInfo
#      26 from ._types import (
#      27     Body,
#      28     IncEx,
#    (...)     35     HttpxRequestFiles,
#      36 )
#
# File c:\Users\heman\OneDrive\Desktop\AFTER BTECH\innomatics\internship\genai\venv\Lib\site-packages\pydantic\__init__.py:5
#       2 from typing import TYPE_CHECKING
#       3 from warnings import warn
# ----> 5 from ._migration import getattr_migration
#       6 from .version import VERSION, _ensure_pydantic_core_version
#       8 _ensure_pydantic_core_version()
#
# File c:\Users\heman\OneDrive\Desktop\AFTER BTECH\innomatics\internship\genai\venv\Lib\site-packages\pydantic\_migration.py:4
#       1 import sys
#       2 from typing import Any, Callable
# ----> 4 from pydantic.warnings import PydanticDeprecatedSince20
#       6 from .version import version_short
#       8 MOVED_IN_V2 = {
#       9     'pydantic.utils:version_info': 'pydantic.version:version_info',
#      10     'pydantic.error_wrappers:ValidationError': 'pydantic:ValidationError',
#    (...)     15     'pydantic.generics:GenericModel': 'pydantic.BaseModel',
#      16 }
#
# File c:\Users\heman\OneDrive\Desktop\AFTER BTECH\innomatics\internship\genai\venv\Lib\site-packages\pydantic\warnings.py:5
#       1 """Pydantic-specific warnings."""
#       3 from __future__ import annotations as _annotations
# ----> 5 from .version import version_short
#       7 __all__ = (
#       8     'PydanticDeprecatedSince20',
#       9     'PydanticDeprecatedSince26',
#    (...)     18     'TypedDictExtraConfigWarning',
#      19 )
#      22 class PydanticDeprecationWarning(DeprecationWarning):
#
# File c:\Users\heman\OneDrive\Desktop\AFTER BTECH\innomatics\internship\genai\venv\Lib\site-packages\pydantic\version.py:7
#       3 from __future__ import annotations as _annotations
#       5 import sys
# ----> 7 from pydantic_core import __version__ as __pydantic_core_version__
#       9 __all__ = 'VERSION', 'version_info'
#      11 VERSION = '2.12.5'
#
# File c:\Users\heman\OneDrive\Desktop\AFTER BTECH\innomatics\internship\genai\venv\Lib\site-packages\pydantic_core\__init__.py:8
#       4 from typing import Any as _Any
#       6 from typing_extensions import Sentinel
# ----> 8 from ._pydantic_core import (
#       9     ArgsKwargs,
#      10     MultiHostUrl,
#      11     PydanticCustomError,
#      12     PydanticKnownError,
#      13     PydanticOmit,
#      14     PydanticSerializationError,
#      15     PydanticSerializationUnexpectedValue,
#      16     PydanticUndefined,
#      17     PydanticUndefinedType,
#      18     PydanticUseDefault,
#      19     SchemaError,
#      20     SchemaSerializer,
#      21     SchemaValidator,
#      22     Some,
#      23     TzInfo,
#      24     Url,
#      25     ValidationError,
#      26     __version__,
#      27     from_json,
#      28     to_json,
#      29     to_jsonable_python,
#      30 )
#      31 from .core_schema import CoreConfig, CoreSchema, CoreSchemaType, ErrorType
#      33 if _sys.version_info < (3, 11):
#
# ModuleNotFoundError: No module named 'pydantic_core._pydantic_core'

# %%
# !pip uninstall groq pydantic -y
# !pip install "pydantic>=2.0" groq
# Out:
# Found existing installation: groq 1.0.0
# Uninstalling groq-1.0.0:
#   Successfully uninstalled groq-1.0.0
# Found existing installation: pydantic 2.12.5
# Uninstalling pydantic-2.12.5:
#   Successfully uninstalled pydantic-2.12.5
# Collecting pydantic>=2.0
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting groq
#   Using cached groq-1.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\heman\onedrive\desktop\after btech\innomatics\internship\genai\venv\lib\site-packages (from pydantic>=2.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\heman\onedrive\desktop\after btech\innomatics\internship\genai\venv\lib\site-packages (from pydantic>=2.0) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\heman\onedrive\desktop\after btech\innomatics\internship\genai\venv\lib\site-packages (from pydantic>=2.0) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\heman\onedrive\desktop\after btech\innomatics\internship\genai\venv\lib\site-packages (from pydantic>=2.0) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\heman\onedrive\desktop\after btech\innomatics\internship\genai\venv\lib\site-packages (from groq) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\heman\onedrive\desktop\after btech\innomatics\internship\genai\venv\lib\site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\heman\onedrive\desktop\after btech\innomatics\internship\genai\venv\lib\site-packages (from groq) (0.28.1)
# Requirement already satisfied: sniffio in c:\users\heman\onedrive\desktop\after btech\innomatics\internship\genai\venv\lib\site-packages (from groq) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\heman\onedrive\desktop\after btech\innomatics\internship\genai\venv\lib\site-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in c:\users\heman\onedrive\desktop\after btech\innomatics\internship\genai\venv\lib\site-packages (from httpx<1,>=0.23.0->groq) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\heman\onedrive\desktop\after btech\innomatics\internship\genai\venv\lib\site-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\heman\onedrive\desktop\after btech\innomatics\internship\genai\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached groq-1.0.0-py3-none-any.whl (138 kB)
# Installing collected packages: pydantic, groq
#
#    ---------------------------------------- 0/2 [pydantic]
#    ---------------------------------------- 0/2 [pydantic]
#    ---------------------------------------- 0/2 [pydantic]
#    ---------------------------------------- 0/2 [pydantic]
#    ---------------------------------------- 0/2 [pydantic]
#    ---------------------------------------- 0/2 [pydantic]
#    ---------------------------------------- 0/2 [pydantic]
#    ---------------------------------------- 0/2 [pydantic]
#    ---------------------------------------- 0/2 [pydantic]
#    -------------------- ------------------- 1/2 [groq]
#    -------------------- ------------------- 1/2 [groq]
#    -------------------- ------------------- 1/2 [groq]
#    -------------------- ------------------- 1/2 [groq]
#    -------------------- ------------------- 1/2 [groq]
#    ---------------------------------------- 2/2 [groq]
#
# Successfully installed groq-1.0.0 pydantic-2.12.5
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
